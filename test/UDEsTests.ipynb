# %%
include("../src/UniversalDiffEq.jl" )
using DataFrames
# Out:
# WARNING: replacing module UniversalDiffEq.
# WARNING: replacing module ObservationModels.
# WARNING: replacing module ProcessModels.
# WARNING: replacing module LossFunctions.
# WARNING: replacing module Regularization.
# WARNING: replacing module ObservationModels.
# WARNING: replacing module ProcessModels.
# WARNING: replacing module LossFunctions.
# WARNING: replacing module Regularization.

# %%
data,plt = UniversalDiffEq.LokaVolterra(T = 2.0)
plt

# %%
#model = UniversalDiffEq.SSNODE(data, obs_weight = 0.5,  proc_weight = 2.0, reg_weight = 10^-4)
model = UniversalDiffEq.ContinuousModelErrors(data, x -> [0.0,0.0], obs_weight = 0.5,  proc_weight = 2.0, reg_weight = 10^-4)
nothing

# %%
UniversalDiffEq.gradient_decent!(model,verbos = true, maxiter = 250)
# Out:
# 0.264 0.224 0.191 0.163 0.138 0.118 0.1 0.085 0.072 0.062 0.053 0.046 0.041 0.036 0.033 0.03 0.028 0.026 0.025 0.024 0.023 0.022 0.021 0.02 0.019 0.019 0.018 0.017 0.017 0.017 0.016 0.016 0.016 0.016 0.015 0.015 0.015 0.015 0.014 0.014 0.014 0.013 0.013 0.013 0.012 0.012 0.012 0.012 0.012 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.011 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 0.01 
# ...

# %%
UniversalDiffEq.BFGS!(model; verbos = true)
# Out:
# 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009 0.009
# ...

# %%
UniversalDiffEq.plot_state_estiamtes(model)

# %%
UniversalDiffEq.plot_predictions(model)

# %%
plt,(p2,p3)=UniversalDiffEq.plot_forecast(model, 100)
plt
