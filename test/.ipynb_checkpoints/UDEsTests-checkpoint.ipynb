# %%
include("../src/UniversalDiffEq.jl" )
using DataFrames

# %%
data,plt = UniversalDiffEq.LokaVolterra(T = 1.0)
plt

# %%
#model = UniversalDiffEq.SSNODE(data, obs_weight = 0.5,  proc_weight = 2.0, reg_weight = 10^-4)
model = UniversalDiffEq.ContinuousModelErrors(data, x -> [0.0,0.0], obs_weight = 0.5,  proc_weight = 2.0, reg_weight = 10^-4)
nothing

# %%
UniversalDiffEq.gradient_decent!(model,verbos = true, maxiter = 250)

# %%
UniversalDiffEq.BFGS!(model; verbos = true)
# Out:
# 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008 0.008
# ComponentVector{Float64}(uhat = [0.9931738651385741 1.0135854203953392 … 0.899381488482748 0.8629402236297495; 0.4470629901536908 0.455046815594688 … 1.1240222052421849 1.1242998956201784], process_model = (NN = (layer_1 = (weight = [0.0002118201752433546 0.00043459399807547865; -1.7887380400727384e-6 -4.285332645651197e-5; … ; 0.00011440448375388314 -0.00014040257762913715; 0.00011627065364974843 -1.6976308985211072e-5], bias = [0.3385859307940503; 0.007838267628543224; … ; 0.49969785180695203; -0.2731217377045298;;]), layer_2 = (weight = [8.924795331631983e-5 4.204490845309965e-5 … 9.188432894256594e-5 -2.604511581832374e-5; 5.234608646784486e-6 -8.521306215042372e-6 … -8.394001778230255e-5 5.4144285783393005e-6], bias = [-0.4433343204042557; 0.6765785265956219;;])), known_dynamics = Float64[]), process_loss = Float64[], observation_model = Float64[], observation_loss = Float64[], process_regularization = Float64[], observation_regularization = Float64[])

# %%
UniversalDiffEq.plot_state_estiamtes(model)

# %%
UniversalDiffEq.plot_predictions(model)

# %%
plt,(p2,p3)=UniversalDiffEq.plot_forecast(model, 700)
plt
# Out:
# type ContinuousModelErrors has no field forecast
#
# Stacktrace:
#  [1] getproperty(x::Main.UniversalDiffEq.ProcessModels.ContinuousModelErrors, f::Symbol)
#    @ Base ./Base.jl:42
#  [2] (::Main.UniversalDiffEq.var"#51#52"{Main.UniversalDiffEq.SSUDE})(x::Vector{Float64}, dt::Float64)
#    @ Main.UniversalDiffEq ~/github/UniversalDiffEq.jl/src/UDEs.jl:677
#  [3] forecast(UDE::Main.UniversalDiffEq.SSUDE, u0::Vector{Float64}, times::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64})
#    @ Main.UniversalDiffEq ~/github/UniversalDiffEq.jl/src/UDEs.jl:686
#  [4] plot_forecast(UDE::Main.UniversalDiffEq.SSUDE, T::Int64)
#    @ Main.UniversalDiffEq ~/github/UniversalDiffEq.jl/src/UDEs.jl:707
#  [5] top-level scope
#    @ In[489]:1
